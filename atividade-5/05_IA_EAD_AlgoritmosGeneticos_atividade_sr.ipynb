# %% [markdown]
# # <font color='red' size='6'>Inteligência Artificial</font>
#
# ## Atividade Prática: Algoritmos Genéticos
#
# Grupo (Máx. 4 alunos) - Integrantes
# <table width="300" border="2">
#     <tr>
#         <td><b>Nome do Aluno</b> </td>
#         <td><b>RA</b></td>
#      </tr>
#    <tr>
#        <td>Aline Yumi Higa </td>
#        <td>10402138</td>
#    </tr>
#    <tr>
#        <td>Gustavo Garabetti Munhoz</td>
#        <td>10409258</td>
#    </tr>
#    <tr>
#        <td>Karine Yoo Lim Choi</td>
#        <td>10403237</td>
#    </tr>
#    <tr>
#        <td>Paula Aguiar Oliveira</td>
#        <td>10403270</td>
#    </tr>
# </table>

# %% [markdown]
# ## Definindo o Problema da Atividade

# %% [markdown]
# Esta atividade consiste em construir a solução de dois exercícios utilizando algoritmos genéticos. Sendo eles:<br>
# 1) <b>Otimização de uma Sequência de DNA</b>, considerando os nucleotídeos adenina (A), citosina (C), guanina (G) e timina (T). <br>
# 2) <b>Otimização de uma Sequência de Notas Musicais</b>. Música: "Parabéns para Você".

# %% [markdown]
# <p><b>Exercício 1: Otimização de uma Sequência de DNA</b>
# <p><b>Contexto:</b>
# A otimização de sequências de DNA é um problema comum em bioinformática e biologia sintética. Algoritmos genéticos podem ser usados para explorar o espaço de possíveis sequências e encontrar a sequência desejada.
#
# <p><b>Objetivo: </b>evoluir uma população de sequências de DNA até que uma delas corresponda a uma sequência pré-definida. Implemente um algoritmo genético que evolua uma população de sequências de DNA até encontrar a sequência que corresponda exatamente à sequência alvo "ATGCCGTATGCCGTA". Os nucleotídeos possíveis são: ['A', 'T', 'C', 'G']. O significado de cada sigla é: adenina (A), citosina (C), guanina (G) e timina (T),
#
# <p><b>Descrição do Problema:</b>
#
# <p><b>1. Parâmetros do Algoritmo:</b></p>
#
# <b>Tamanho da população:</b> 50 indivíduos.<br>
#
# <b>Taxa de crossover:</b> 80%.<br>
#
# <b>Taxa de mutação:</b> 5%.<br>
#
# <b>Número máximo de gerações:</b> 1000.<br>
#
# <b>Comprimento da sequência:</b> 15. <br>
#
# <p><b>Entrada:</b></p>
# <b>Sequência alvo:</b> "ATGCCGTATGCCGTA".<br>
# <b>Nucleotídeos possíveis:</b> ['A', 'T', 'C', 'G'].<br><br>
#
# <p><b>Saída Esperada:</b></p>
# A sequência de DNA evolvida que corresponde exatamente à sequência alvo.
# O número de gerações necessárias para encontrar a solução.<br><br>
#
# <p><b>2. Representação do Indivíduo:</b></p>
#
# Cada indivíduo na população é representado por uma sequência de DNA, que é uma cadeia de nucleotídeos (A, T, C, G). Por exemplo, uma sequência pode ser "ATGCCGTATGCCGTA".<br>
#
# <p><b>3. Função de Avaliação (Fitness):</b></p>
#
# A função de fitness deve avaliar quão próxima uma sequência de DNA está da sequência alvo. A pontuação de fitness pode ser calculada como o número de nucleotídeos corretos na posição correta. Por exemplo:<br>
#
# <b>Sequência alvo:</b> "ATGCCGTATGCCGTA"<br>
#
# <b>Sequência candidata:</b> "ATGCCGTCTGCCGTA"<br>
#
# <b>Fitness:</b> 14 (pois 14 nucleotídeos estão corretos).<br>
#
# <p><b>4. Operadores Genéticos:</b></p>
#
# <p><b>Seleção:</b> Utilize um método de seleção (como roleta ou torneio) para escolher os indivíduos mais aptos para reprodução.
#
# <p><b>Crossover:</b> Implemente um operador de crossover para combinar duas sequências de DNA e gerar descendentes.
#
# <p><b>Mutação:</b> Aplique mutação para introduzir diversidade na população. A mutação pode alterar aleatoriamente um nucleotídeo em uma sequência.
#
# <p><b>5. Critério de Parada:</b></p>
#
# O algoritmo deve parar quando encontrar uma sequência de DNA com fitness máximo (ou seja, quando a sequência candidata for idêntica à sequência alvo).

# %%
import random
from functools import reduce

TAM_POPULACAO = 50
TAXA_CROSSOVER = 0.8
TAXA_MUTACAO = 0.05
MAX_GERACOES = 1000
COMP_SEQ = 15
NUCLEOTIDEOS = ['A', 'T', 'C', 'G']
TARGET = "ATGCCGTATGCCGTA"

def gerar_individuo():
    return reduce(lambda x, y: x + y, [random.choice(NUCLEOTIDEOS) for _ in range(COMP_SEQ)])

def calc_fitness(individuo):
    return sum(1 for i in range(COMP_SEQ) if individuo[i] == TARGET[i])

def selecionar_pais(populacao):
    pais = []
    for _ in range(TAM_POPULACAO):
        competidores = random.sample(populacao, 3)
        melhor = max(competidores, key=calc_fitness)
        pais.append(melhor)
    return pais

def crossover(pai1, pai2):
    if random.random() < TAXA_CROSSOVER:
        ponto_corte = random.randint(1, COMP_SEQ - 1)
        filho1 = pai1[:ponto_corte] + pai2[ponto_corte:]
        filho2 = pai2[:ponto_corte] + pai2[ponto_corte:]
        return filho1, filho2
    else:
        return pai1, pai2

def mutar(individuo):
    new_ind = ''
    for i in range(COMP_SEQ):
        new_ind += random.choice(NUCLEOTIDEOS) if random.random() < TAXA_MUTACAO else individuo[i]
    return new_ind

def algoritmo_genetico():
    populacao = [gerar_individuo() for _ in range(TAM_POPULACAO)]

    for geracao in range(MAX_GERACOES):

        fitness_populacao = [calc_fitness(individuo) for individuo in populacao]
        melhor_fitness = max(fitness_populacao)
        melhor_individuo = populacao[fitness_populacao.index(melhor_fitness)]

        print(f"Geracao {geracao}: Melhor individuo = {melhor_individuo}, Fitness = {melhor_fitness}")

        if melhor_fitness == COMP_SEQ:
            print(f"Solução encontrada na geração {geracao}: {melhor_individuo}")
            return melhor_individuo

        pais = selecionar_pais(populacao)

        nova_populacao = []
        for i in range(0, TAM_POPULACAO, 2):
            pai1, pai2 = pais[i], pais[i+1]
            filho1, filho2 = crossover(pai1, pai2)
            nova_populacao.append(mutar(filho1))
            nova_populacao.append(mutar(filho2))

        populacao = nova_populacao

    print("Solução não encontrada dentro do número máximo de gerações.")
    return None

if __name__ == "__main__":
    solucao = algoritmo_genetico()
    if solucao:
        print("Sequência evoluida:", solucao)
# Out:
# Geracao 0: Melhor individuo = CAGGCCTACGTCATT, Fitness = 7
# Geracao 1: Melhor individuo = CGGGCGCAGGCCCGA, Fitness = 8
# Geracao 2: Melhor individuo = ACACCCCTCGCCGTC, Fitness = 8
# Geracao 3: Melhor individuo = ACACCCCACGCCGTC, Fitness = 9
# Geracao 4: Melhor individuo = ATGCCATACGCAGTC, Fitness = 11
# Geracao 5: Melhor individuo = ATGCCGTAAGCAGTC, Fitness = 12
# Geracao 6: Melhor individuo = ATGCCATACGCCGTC, Fitness = 12
# Geracao 7: Melhor individuo = ATGCCGTACGCAGTC, Fitness = 12
# Geracao 8: Melhor individuo = ATGCCATAAGCCGTC, Fitness = 12
# Geracao 9: Melhor individuo = ATGCCATACGCCGTC, Fitness = 12
# Geracao 10: Melhor individuo = ATGCCATACGCCGTC, Fitness = 12
# Geracao 11: Melhor individuo = ATGCCATATGCCGTC, Fitness = 13
# Geracao 12: Melhor individuo = ATGCCATATGCCGTC, Fitness = 13
# Geracao 13: Melhor individuo = ATGCCATATGCCGTA, Fitness = 14
# Geracao 14: Melhor individuo = ATGCCATATGCCGTA, Fitness = 14
# Geracao 15: Melhor individuo = ATGCCATATGCCGTA, Fitness = 14
# Geracao 16: Melhor individuo = ATGCCGTATGCCGTA, Fitness = 15
# Solução encontrada na geração 16: ATGCCGTATGCCGTA
# Sequência evoluida: ATGCCGTATGCCGTA

# %% [markdown]
# <p><b>Exercício 2: Otimização de uma Sequência de Notas Musicais. Música: "Parabéns para Você"</b>
#
# <p><b>Contexto:</b></p>
# A otimização de sequências de notas musicais é um problema interessante na área de computação musical. Algoritmos genéticos podem ser usados para explorar o espaço de possíveis sequências e encontrar a sequência desejada.<br><br>
#
# <p><b>Objetivo:</b> evoluir uma população de sequências de notas até que uma delas corresponda a uma sequência pré-definida.  Implemente um algoritmo genético que evolua uma população de sequências de notas musicais até encontrar a sequência que corresponda exatamente à sequência alvo da música "Parabéns para Você".<br>
#
# <b>Onde:</b>
#
# Primeira Frase (<b>"Parabéns pra você"</b>):<br>
#
# Sol, Sol, Lá, Sol, Dó, Si: Representa a melodia da primeira linha da música.<br>
#
# Segunda Frase (<b>"Nesta data querida"</b>):<br>
#
# Sol, Sol, Lá, Sol, Ré, Dó: Representa a melodia da segunda linha.<br>
#
# Terceira Frase (<b>"Muitas felicidades"</b>):<br>
#
# Sol, Sol, Sol, Mi, Dó, Si, Lá: Representa a melodia da terceira linha.<br>
#
# Quarta Frase (<b>"Muitos anos de vida"</b>):<br>
#
# Fá, Fá, Mi, Dó, Ré, Dó: Representa a melodia da quarta linha.<br>
#
# <p><b>Descrição do Problema:</b></p>
#
# <p><b>1. Parâmetros do Algoritmo:</b></p>
#
# <b>Tamanho da população: </b>200 indivíduos.<br>
#
# <b>Taxa de crossover:</b> 95%.<br>
#
# <b>Taxa de mutação:</b> 10%.<br>
#
# <b>Número máximo de gerações:</b> 1000.<br>
#
# <b>Comprimento da sequência:</b> 25.<br>
#
# <b>Entrada:</b><br>
# <b>Sequência alvo:</b> ["Sol", "Sol", "Lá", "Sol", "Dó", "Si", "Sol", "Sol", "Lá", "Sol", "Ré", "Dó", "Sol", "Sol", "Sol", "Mi", "Dó", "Si", "Lá", "Fá", "Fá", "Mi", "Dó", "Ré", "Dó"].<br>
#
# <b>Notas possíveis:</b> ["Dó", "Ré", "Mi", "Fá", "Sol", "Lá", "Si"].<br>
#
# <b>Saída Esperada:</b><br>
# A sequência de notas evolvida que corresponde exatamente à sequência alvo.<br>
#
# O número de gerações necessárias para encontrar a solução.<br>
#
# <p><b>2. Representação do Indivíduo:</b></p>
#
# Cada indivíduo na população é representado por uma sequência de notas musicais, que é uma cadeia de notas (por exemplo, ["Sol", "Sol", "Lá", "Sol", "Dó", "Si"]). <br>
#
# <p><b>3. Função de Avaliação (Fitness):</b></p>
#
# A função de fitness deve avaliar quão próxima uma sequência de notas está da sequência alvo. A pontuação de fitness pode ser calculada como o número de notas corretas na posição correta. Por exemplo:<br>
#
# <b>Sequência alvo:</b> ["Sol", "Sol", "Lá", "Sol", "Dó", "Si"]<br>
#
# <b>Sequência candidata:</b> ["Sol", "Sol", "Lá", "Sol", "Ré", "Si"]<br>
#
# <b>Fitness:</b> 4 (pois 4 notas estão corretas).<br>
#
# <p><b>4. Operadores Genéticos:</b></p>
#
# <p><b>Seleção:</b> Utilize um método de seleção (como roleta ou torneio) para escolher os indivíduos mais aptos para reprodução. Sugestão: selecione aleatóriamente 5 indivíduos por meio do torneio.<br>
#
# <p><b>Crossover:</b> Implemente um operador de crossover para combinar duas sequências de notas e gerar descendentes. <br>
#
# <p><b>Mutação:</b> Aplique mutação para introduzir diversidade na população. A mutação pode alterar aleatoriamente uma nota em uma sequência.<br>
#
# <p><b>5. Critério de Parada:</b></p>
#
# O algoritmo deve parar quando encontrar uma sequência de notas com fitness máximo (ou seja, quando a sequência candidata for idêntica à sequência alvo).

# %%
import random

TAM_POPULACAO = 200
TAXA_CROSSOVER = 0.95
TAXA_MUTACAO = 0.1
MAX_GERACOES = 1000
COMP_SEQ = 25
NOTAS = ['Dó', 'Ré', 'Mi', 'Fá', 'Sol', 'Lá', 'Si']
TARGET = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó']

def gerar_individuo():
    return [random.choice(NUCLEOTIDEOS) for _ in range(COMP_SEQ)]

def calc_fitness(individuo):
    return sum(1 for i in range(COMP_SEQ) if individuo[i] == TARGET[i])

def selecionar_pais(populacao):
    pais = []
    for _ in range(TAM_POPULACAO):
        competidores = random.sample(populacao, 3)
        melhor = max(competidores, key=calc_fitness)
        pais.append(melhor)
    return pais

def crossover(pai1, pai2):
    if random.random() < TAXA_CROSSOVER:
        ponto_corte = random.randint(1, COMP_SEQ - 1)
        filho1 = pai1[:ponto_corte] + pai2[ponto_corte:]
        filho2 = pai2[:ponto_corte] + pai2[ponto_corte:]
        return filho1, filho2
    else:
        return pai1, pai2

def mutar(individuo):
    for i in range(COMP_SEQ):
        if random.random() < TAXA_MUTACAO:
            individuo[i] = random.choice(NOTAS)
    return individuo

def algoritmo_genetico():
    populacao = [gerar_individuo() for _ in range(TAM_POPULACAO)]

    for geracao in range(MAX_GERACOES):

        fitness_populacao = [calc_fitness(individuo) for individuo in populacao]
        melhor_fitness = max(fitness_populacao)
        melhor_individuo = populacao[fitness_populacao.index(melhor_fitness)]

        print(f"Geracao {geracao}: Melhor individuo = {melhor_individuo}, Fitness = {melhor_fitness}")

        if melhor_fitness == COMP_SEQ:
            print(f"Solução encontrada na geração {geracao}: {melhor_individuo}")
            return melhor_individuo

        pais = selecionar_pais(populacao)

        nova_populacao = []
        for i in range(0, TAM_POPULACAO, 2):
            pai1, pai2 = pais[i], pais[i+1]
            filho1, filho2 = crossover(pai1, pai2)
            nova_populacao.append(mutar(filho1))
            nova_populacao.append(mutar(filho2))

        populacao = nova_populacao

    print("Solução não encontrada dentro do número máximo de gerações.")
    return None

if __name__ == "__main__":
    solucao = algoritmo_genetico()
    if solucao:
        print("Sequência evoluida:", solucao)
# Out:
# Geracao 0: Melhor individuo = ['C', 'A', 'T', 'C', 'C', 'G', 'A', 'C', 'C', 'T', 'G', 'C', 'G', 'A', 'T', 'C', 'T', 'G', 'A', 'A', 'A', 'T', 'G', 'A', 'T'], Fitness = 0
# Geracao 1: Melhor individuo = ['C', 'Mi', 'T', 'T', 'T', 'C', 'A', 'C', 'C', 'Sol', 'Ré', 'C', 'C', 'T', 'A', 'G', 'T', 'G', 'G', 'T', 'T', 'A', 'Dó', 'G', 'G'], Fitness = 3
# Geracao 2: Melhor individuo = ['A', 'T', 'C', 'T', 'C', 'Fá', 'C', 'Sol', 'G', 'Mi', 'T', 'Dó', 'G', 'T', 'G', 'A', 'T', 'T', 'Lá', 'G', 'A', 'Mi', 'T', 'T', 'Mi'], Fitness = 4
# Geracao 3: Melhor individuo = ['Fá', 'Mi', 'T', 'T', 'T', 'C', 'A', 'C', 'C', 'Sol', 'Ré', 'C', 'Sol', 'C', 'Sol', 'Mi', 'G', 'C', 'Fá', 'C', 'G', 'T', 'Si', 'T', 'A'], Fitness = 5
# Geracao 4: Melhor individuo = ['T', 'Sol', 'Dó', 'A', 'Sol', 'T', 'G', 'T', 'Lá', 'C', 'C', 'Dó', 'Dó', 'T', 'Dó', 'Dó', 'G', 'Si', 'Fá', 'Fá', 'G', 'Mi', 'C', 'T', 'T'], Fitness = 6
# Geracao 5: Melhor individuo = ['A', 'Fá', 'G', 'A', 'Dó', 'Si', 'T', 'Si', 'G', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'C', 'A', 'G', 'Si', 'Ré', 'C', 'Sol', 'Fá', 'Dó', 'Lá', 'Dó'], Fitness = 9
# Geracao 6: Melhor individuo = ['Fá', 'Dó', 'G', 'A', 'Dó', 'Si', 'T', 'Fá', 'G', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'C', 'Mi', 'G', 'Sol', 'Lá', 'G', 'Ré', 'Mi', 'T', 'T', 'Lá'], Fitness = 9
# Geracao 7: Melhor individuo = ['Sol', 'G', 'Lá', 'Fá', 'T', 'Si', 'Lá', 'Ré', 'G', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'C', 'Mi', 'G', 'Sol', 'Lá', 'G', 'Ré', 'Mi', 'T', 'T', 'Lá'], Fitness = 10
# Geracao 8: Melhor individuo = ['Sol', 'G', 'Lá', 'Fá', 'T', 'Si', 'Lá', 'Ré', 'G', 'Sol', 'Ré', 'Dó', 'Ré', 'Mi', 'C', 'Mi', 'G', 'Sol', 'Lá', 'Fá', 'Ré', 'Mi', 'T', 'T', 'Lá'], Fitness = 10
# Geracao 9: Melhor individuo = ['Sol', 'G', 'Lá', 'Fá', 'T', 'Si', 'Lá', 'Sol', 'Mi', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'C', 'Mi', 'G', 'Sol', 'Lá', 'G', 'Ré', 'Mi', 'T', 'T', 'Lá'], Fitness = 11
# Geracao 10: Melhor individuo = ['Si', 'Sol', 'Fá', 'Sol', 'Dó', 'Ré', 'Sol', 'Ré', 'Fá', 'Lá', 'Lá', 'Dó', 'Sol', 'Mi', 'Sol', 'G', 'Dó', 'Si', 'Fá', 'Sol', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 13
# Geracao 11: Melhor individuo = ['Sol', 'G', 'Lá', 'Fá', 'Dó', 'Ré', 'Sol', 'Ré', 'Fá', 'Lá', 'Lá', 'Dó', 'Sol', 'Mi', 'Sol', 'G', 'Dó', 'Si', 'Fá', 'Sol', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 13
# Geracao 12: Melhor individuo = ['Sol', 'G', 'Lá', 'Fá', 'Si', 'Si', 'Lá', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Ré', 'Mi', 'Sol', 'G', 'Dó', 'Si', 'Fá', 'Sol', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 14
# Geracao 13: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Sol', 'Fá', 'Dó', 'Sol', 'Fá', 'Mi', 'Mi', 'G', 'Sol', 'Lá', 'Ré', 'Sol', 'Lá', 'Dó', 'Ré', 'Mi'], Fitness = 14
# Geracao 14: Melhor individuo = ['Lá', 'Sol', 'Fá', 'Sol', 'Dó', 'Ré', 'Sol', 'Ré', 'G', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Fá', 'Sol', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 15
# Geracao 15: Melhor individuo = ['Sol', 'Lá', 'Ré', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'T', 'Dó', 'Ré', 'Mi', 'Mi', 'Dó', 'Si', 'Fá', 'Si', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 15
# Geracao 16: Melhor individuo = ['Sol', 'Sol', 'Dó', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'T', 'Dó', 'Ré', 'Mi', 'Mi', 'Dó', 'Si', 'Fá', 'Si', 'Fá', 'Mi', 'Lá', 'Ré', 'Dó'], Fitness = 16
# Geracao 17: Melhor individuo = ['Si', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Fá', 'Ré', 'Lá', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Dó', 'Si', 'Fá', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 16
# Geracao 18: Melhor individuo = ['Ré', 'Sol', 'Ré', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Ré', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'G', 'Mi', 'Dó', 'Fá', 'Dó'], Fitness = 17
# Geracao 19: Melhor individuo = ['Ré', 'Sol', 'Ré', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Mi', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Dó', 'Si', 'Sol', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 17
# Geracao 20: Melhor individuo = ['Si', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Dó', 'Mi', 'Ré', 'Mi', 'Mi', 'Si', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 17
# Geracao 21: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Ré', 'Mi', 'Ré', 'Mi', 'Mi', 'Sol', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 17
# Geracao 22: Melhor individuo = ['Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Mi', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Dó', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 17
# Geracao 23: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Ré', 'Mi', 'Ré', 'Mi', 'Mi', 'Sol', 'Si', 'Fá', 'Fá', 'Fá', 'Si', 'Dó', 'Ré', 'Dó'], Fitness = 17
# Geracao 24: Melhor individuo = ['Ré', 'Fá', 'Ré', 'Sol', 'Fá', 'Si', 'Si', 'Sol', 'Lá', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Mi', 'Ré', 'Dó'], Fitness = 17
# Geracao 25: Melhor individuo = ['Ré', 'Fá', 'Ré', 'Sol', 'Fá', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Mi', 'Ré', 'Dó'], Fitness = 18
# Geracao 26: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Ré', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Mi', 'Ré', 'Dó'], Fitness = 20
# Geracao 27: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Fá', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Si', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Mi', 'Ré', 'Dó'], Fitness = 19
# Geracao 28: Melhor individuo = ['Si', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Mi', 'Lá', 'Si', 'Lá', 'Fá', 'Lá', 'Dó', 'Dó', 'Ré', 'Mi'], Fitness = 18
# Geracao 29: Melhor individuo = ['Sol', 'Dó', 'Ré', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Ré', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 19
# Geracao 30: Melhor individuo = ['Sol', 'Mi', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Dó', 'Ré', 'Dó', 'Ré', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 20
# Geracao 31: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Dó', 'Sol', 'Mi', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Lá', 'Si', 'Lá', 'Si', 'Fá', 'Mi', 'Dó', 'Lá', 'Dó'], Fitness = 19
# Geracao 32: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Dó', 'Si', 'Si', 'Lá', 'Lá', 'Sol', 'Ré', 'Dó', 'Ré', 'Mi', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 19
# Geracao 33: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Dó', 'Mi', 'Sol', 'Sol', 'Mi', 'G', 'Si', 'Fá', 'Mi', 'Fá', 'Mi', 'Dó', 'Ré', 'Si'], Fitness = 19
# Geracao 34: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Fá', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 21
# Geracao 35: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Ré', 'Mi', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 21
# Geracao 36: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 37: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 38: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 39: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Lá', 'Ré', 'Si'], Fitness = 20
# Geracao 40: Melhor individuo = ['Mi', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Lá', 'Ré', 'Dó'], Fitness = 20
# Geracao 41: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Mi', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Si', 'Dó', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 42: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Fá', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Si', 'Fá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 43: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Mi', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Ré', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Dó', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 44: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Mi', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Ré', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Sol', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 45: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Fá', 'Fá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 46: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 23
# Geracao 47: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 23
# Geracao 48: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Fá', 'Ré', 'Dó'], Fitness = 22
# Geracao 49: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Lá'], Fitness = 21
# Geracao 50: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 22
# Geracao 51: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Lá', 'Mi', 'Ré', 'Dó'], Fitness = 22
# Geracao 52: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Lá', 'Mi', 'Ré', 'Dó'], Fitness = 22
# Geracao 53: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Lá', 'Mi', 'Ré', 'Si'], Fitness = 21
# Geracao 54: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 23
# Geracao 55: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 23
# Geracao 56: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Ré', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 22
# Geracao 57: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Dó', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 58: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Dó', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 59: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Sol', 'Dó'], Fitness = 21
# Geracao 60: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 21
# Geracao 61: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 21
# Geracao 62: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Mi'], Fitness = 21
# Geracao 63: Melhor individuo = ['Sol', 'Mi', 'Lá', 'Dó', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 20
# Geracao 64: Melhor individuo = ['Si', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Si', 'Si', 'Dó'], Fitness = 20
# Geracao 65: Melhor individuo = ['Sol', 'Si', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 21
# Geracao 66: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 22
# Geracao 67: Melhor individuo = ['Dó', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 21
# Geracao 68: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 22
# Geracao 69: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Ré', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 21
# Geracao 70: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Dó', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 71: Melhor individuo = ['Dó', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Lá', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 72: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Dó', 'Ré', 'Lá', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Fá', 'Dó'], Fitness = 21
# Geracao 73: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Ré', 'Lá', 'Sol', 'Lá', 'Dó', 'Ré', 'Lá', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Fá', 'Dó'], Fitness = 20
# Geracao 74: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Dó', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Fá', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Mi', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 19
# Geracao 75: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Lá', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Fá', 'Ré'], Fitness = 21
# Geracao 76: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Dó', 'Lá', 'Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 21
# Geracao 77: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Si', 'Si', 'Lá', 'Fá', 'Mi', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 20
# Geracao 78: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Dó', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 79: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Fá', 'Dó', 'Si', 'Sol', 'Sol', 'Si', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 80: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Mi', 'Mi', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Lá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 81: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Ré', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 19
# Geracao 82: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Ré', 'Sol', 'Sol', 'Si', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 83: Melhor individuo = ['Mi', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Dó', 'Dó', 'Mi', 'Dó'], Fitness = 21
# Geracao 84: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Lá', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá'], Fitness = 20
# Geracao 85: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Lá'], Fitness = 21
# Geracao 86: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Lá'], Fitness = 21
# Geracao 87: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Fá', 'Lá'], Fitness = 21
# Geracao 88: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Mi', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Fá', 'Dó'], Fitness = 21
# Geracao 89: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Dó', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 90: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Dó', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 91: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Mi', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 92: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 93: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Dó', 'Mi', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 94: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Ré'], Fitness = 21
# Geracao 95: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Lá', 'Lá', 'Ré', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 96: Melhor individuo = ['Mi', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Fá', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 20
# Geracao 97: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Si', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Mi', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 98: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Ré', 'Ré', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 99: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Lá', 'Lá', 'Ré', 'Ré', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 100: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Si', 'Mi', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Fá'], Fitness = 20
# Geracao 101: Melhor individuo = ['Sol', 'Fá', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 102: Melhor individuo = ['Sol', 'Ré', 'Fá', 'Sol', 'Dó', 'Dó', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Dó', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Ré'], Fitness = 20
# Geracao 103: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 104: Melhor individuo = ['Sol', 'Ré', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Si', 'Fá', 'Fá', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 105: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Si', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 106: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Si', 'Lá', 'Mi', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 107: Melhor individuo = ['Sol', 'Dó', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 22
# Geracao 108: Melhor individuo = ['Sol', 'Dó', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 109: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Fá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 110: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Lá', 'Sol', 'Si', 'Dó', 'Fá', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 111: Melhor individuo = ['Sol', 'Fá', 'Lá', 'Ré', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Dó', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 112: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 113: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Dó', 'Dó', 'Mi', 'Sol'], Fitness = 21
# Geracao 114: Melhor individuo = ['Sol', 'Fá', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 21
# Geracao 115: Melhor individuo = ['Mi', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Fá', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 116: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Fá'], Fitness = 21
# Geracao 117: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Fá', 'Dó'], Fitness = 21
# Geracao 118: Melhor individuo = ['Dó', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Lá', 'Dó'], Fitness = 21
# Geracao 119: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Dó', 'Sol', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Fá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 120: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Mi', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 121: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Mi', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 122: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 123: Melhor individuo = ['Sol', 'Dó', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Lá', 'Dó'], Fitness = 20
# Geracao 124: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Si'], Fitness = 21
# Geracao 125: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 23
# Geracao 126: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Lá', 'Dó'], Fitness = 21
# Geracao 127: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Ré', 'Si', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 128: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 22
# Geracao 129: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 22
# Geracao 130: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Mi', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 21
# Geracao 131: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Ré', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Si', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Si', 'Dó'], Fitness = 20
# Geracao 132: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Sol', 'Fá', 'Sol', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 21
# Geracao 133: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Dó', 'Si', 'Sol', 'Fá', 'Si', 'Sol', 'Ré', 'Mi', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 134: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Ré', 'Lá', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 135: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Ré', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Sol'], Fitness = 20
# Geracao 136: Melhor individuo = ['Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Dó', 'Sol', 'Mi', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 137: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Dó', 'Fá', 'Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 138: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 139: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Si', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 140: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 141: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 142: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Sol', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Lá'], Fitness = 21
# Geracao 143: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Fá', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Mi', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 21
# Geracao 144: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Fá', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Lá', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 145: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Mi', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Lá', 'Si', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 146: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Si', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 147: Melhor individuo = ['Sol', 'Fá', 'Lá', 'Sol', 'Lá', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Fá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 148: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Dó', 'Sol', 'Ré', 'Fá', 'Sol', 'Sol', 'Ré', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Dó', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 149: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 150: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Mi', 'Ré', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 151: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Lá', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Fá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 152: Melhor individuo = ['Sol', 'Ré', 'Lá', 'Sol', 'Lá', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Fá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 153: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Fá', 'Dó', 'Sol', 'Sol', 'Fá', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Lá', 'Ré', 'Dó'], Fitness = 21
# Geracao 154: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Fá', 'Ré', 'Dó'], Fitness = 22
# Geracao 155: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Ré', 'Sol', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 156: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Dó', 'Dó', 'Fá', 'Sol', 'Fá', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 157: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 20
# Geracao 158: Melhor individuo = ['Sol', 'Si', 'Sol', 'Fá', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 159: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Ré', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 160: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Sol', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 161: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Dó', 'Lá', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Lá', 'Mi', 'Dó', 'Sol', 'Dó'], Fitness = 20
# Geracao 162: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Dó', 'Lá', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 163: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Mi', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 164: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 165: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 166: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Lá', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 167: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'Sol', 'Mi', 'Si', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 168: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Ré', 'Dó', 'Si', 'Lá', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Si', 'Fá', 'Mi', 'Dó', 'Ré', 'Lá'], Fitness = 20
# Geracao 169: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Fá', 'Sol', 'Mi', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Lá', 'Dó'], Fitness = 20
# Geracao 170: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Dó', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 171: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Dó', 'Sol', 'Sol', 'Mi', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Dó', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 172: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Sol'], Fitness = 20
# Geracao 173: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Fá', 'Mi', 'Mi', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 174: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Ré', 'Mi', 'Dó', 'Mi', 'Lá'], Fitness = 19
# Geracao 175: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Mi', 'Lá', 'Fá', 'Fá', 'Mi', 'Fá', 'Ré', 'Dó'], Fitness = 20
# Geracao 176: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Dó', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Si', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Dó', 'Sol', 'Ré', 'Dó'], Fitness = 19
# Geracao 177: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Lá', 'Si', 'Dó', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 20
# Geracao 178: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Ré', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Lá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Mi', 'Ré', 'Dó'], Fitness = 21
# Geracao 179: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Ré', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 180: Melhor individuo = ['Fá', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Ré', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Sol', 'Ré', 'Dó'], Fitness = 20
# Geracao 181: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Lá', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Lá', 'Sol', 'Ré', 'Dó'], Fitness = 20
# Geracao 182: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Dó', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Fá'], Fitness = 22
# Geracao 183: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Ré', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Fá'], Fitness = 20
# Geracao 184: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Ré', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Dó', 'Mi', 'Fá', 'Lá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 19
# Geracao 185: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Si', 'Dó', 'Si', 'Dó'], Fitness = 20
# Geracao 186: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Ré', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Fá', 'Fá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 187: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Si', 'Dó', 'Si', 'Dó'], Fitness = 20
# Geracao 188: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Lá', 'Lá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 189: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Ré', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Mi', 'Sol', 'Dó', 'Si', 'Lá', 'Fá', 'Si', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 190: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Lá', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Si', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 191: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Ré', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 192: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Si', 'Si', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 193: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Ré', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Ré', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Mi'], Fitness = 20
# Geracao 194: Melhor individuo = ['Sol', 'Dó', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 195: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Si', 'Si', 'Fá', 'Ré', 'Fá', 'Sol', 'Ré', 'Ré', 'Dó'], Fitness = 20
# Geracao 196: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Si', 'Fá', 'Mi', 'Dó', 'Ré', 'Lá'], Fitness = 20
# Geracao 197: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 22
# Geracao 198: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 23
# Geracao 199: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Si', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 200: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Si', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 201: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 202: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Si', 'Dó'], Fitness = 21
# Geracao 203: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Si', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Si', 'Dó', 'Si', 'Dó'], Fitness = 20
# Geracao 204: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Lá', 'Lá', 'Sol', 'Sol', 'Si', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 20
# Geracao 205: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Lá', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Si', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 206: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Lá', 'Sol', 'Ré', 'Mi', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 207: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Lá', 'Lá', 'Sol', 'Ré', 'Lá', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 208: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Mi', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 209: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 210: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Fá', 'Ré', 'Sol', 'Ré', 'Mi', 'Sol', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 211: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Dó', 'Lá', 'Ré', 'Dó'], Fitness = 20
# Geracao 212: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Lá', 'Mi', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 213: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Lá', 'Mi', 'Lá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 214: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Mi', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Mi', 'Mi', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Ré', 'Mi', 'Dó', 'Dó', 'Dó'], Fitness = 20
# Geracao 215: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Ré', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Lá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 20
# Geracao 216: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Lá', 'Sol', 'Lá', 'Dó', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 19
# Geracao 217: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Mi', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Ré', 'Mi', 'Dó', 'Si', 'Sol', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Mi'], Fitness = 20
# Geracao 218: Melhor individuo = ['Sol', 'Mi', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Si', 'Mi', 'Lá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Si', 'Dó', 'Dó'], Fitness = 20
# Geracao 219: Melhor individuo = ['Sol', 'Sol', 'Mi', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Dó', 'Ré', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 220: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Mi', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Si', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Fá'], Fitness = 19
# Geracao 221: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Sol'], Fitness = 21
# Geracao 222: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Dó', 'Ré', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 223: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Dó', 'Ré', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 224: Melhor individuo = ['Sol', 'Si', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Dó', 'Mi', 'Dó', 'Si', 'Dó', 'Ré', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 225: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Ré', 'Dó', 'Mi', 'Dó', 'Si', 'Dó', 'Ré', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 226: Melhor individuo = ['Sol', 'Sol', 'Mi', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Lá', 'Dó', 'Ré', 'Sol', 'Ré', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Ré', 'Mi', 'Dó', 'Fá', 'Dó'], Fitness = 19
# Geracao 227: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Fá', 'Dó', 'Fá', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 228: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Sol', 'Ré', 'Dó'], Fitness = 20
# Geracao 229: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Si', 'Sol', 'Ré', 'Dó', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Mi', 'Fá', 'Dó'], Fitness = 20
# Geracao 230: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Si', 'Sol', 'Si', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Si', 'Mi', 'Ré', 'Dó'], Fitness = 20
# Geracao 231: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Si', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 232: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Fá', 'Ré', 'Mi'], Fitness = 21
# Geracao 233: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Ré', 'Sol', 'Ré', 'Dó', 'Si', 'Lá', 'Sol', 'Mi', 'Dó', 'Dó', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 234: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Dó', 'Sol', 'Ré', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# ...
# Geracao 923: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Lá', 'Ré', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Lá', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 924: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 22
# Geracao 925: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Dó', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 926: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Lá', 'Dó', 'Ré', 'Si'], Fitness = 22
# Geracao 927: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Mi', 'Fá', 'Fá', 'Lá', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 928: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Dó', 'Lá', 'Lá', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 929: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Dó', 'Lá', 'Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 930: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Dó', 'Lá', 'Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 931: Melhor individuo = ['Sol', 'Lá', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Si', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 932: Melhor individuo = ['Dó', 'Sol', 'Si', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 21
# Geracao 933: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Dó', 'Dó', 'Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Mi', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 934: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Ré', 'Ré', 'Dó'], Fitness = 20
# Geracao 935: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Ré'], Fitness = 20
# Geracao 936: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 937: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Fá', 'Lá', 'Sol', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 938: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Ré', 'Sol', 'Ré', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Fá', 'Dó', 'Ré', 'Ré'], Fitness = 20
# Geracao 939: Melhor individuo = ['Sol', 'Mi', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Ré', 'Ré', 'Ré', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 940: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Sol', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 941: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Mi', 'Mi', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 942: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Ré', 'Dó', 'Ré', 'Ré'], Fitness = 20
# Geracao 943: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 944: Melhor individuo = ['Fá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 945: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Mi', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Si', 'Lá', 'Si', 'Lá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 946: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Sol'], Fitness = 21
# Geracao 947: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Mi', 'Sol', 'Lá', 'Sol', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Sol'], Fitness = 21
# Geracao 948: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Sol', 'Lá', 'Lá', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Si', 'Dó', 'Fá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 949: Melhor individuo = ['Sol', 'Ré', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Ré', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 950: Melhor individuo = ['Sol', 'Si', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Mi', 'Sol', 'Ré', 'Fá', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 951: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Lá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Ré', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 952: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Lá', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 953: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Lá', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Dó', 'Ré', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 954: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Ré', 'Ré', 'Fá', 'Lá', 'Si', 'Sol', 'Lá', 'Dó', 'Si', 'Sol', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 19
# Geracao 955: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Lá', 'Sol', 'Lá', 'Sol', 'Lá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Fá', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 956: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Dó', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Sol', 'Si', 'Ré', 'Dó', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 957: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Lá', 'Sol', 'Sol', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 958: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Dó', 'Dó', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Lá', 'Si', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 959: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Dó', 'Fá', 'Mi', 'Dó', 'Dó', 'Lá'], Fitness = 20
# Geracao 960: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Mi', 'Si', 'Lá', 'Sol', 'Sol', 'Mi', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 961: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Mi', 'Fá', 'Sol', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 962: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Sol', 'Fá', 'Sol', 'Mi', 'Sol', 'Ré', 'Dó', 'Sol', 'Dó', 'Sol', 'Mi', 'Dó', 'Mi', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 963: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Si', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 964: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 965: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Si', 'Sol', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Mi', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Lá'], Fitness = 20
# Geracao 966: Melhor individuo = ['Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Sol', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Mi', 'Lá', 'Sol', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 967: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 968: Melhor individuo = ['Sol', 'Sol', 'Dó', 'Sol', 'Dó', 'Si', 'Si', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Si', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 969: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Mi', 'Si', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Dó', 'Mi', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Lá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 970: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Si', 'Ré', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Mi', 'Mi', 'Lá', 'Ré', 'Dó'], Fitness = 20
# Geracao 971: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Sol', 'Lá', 'Mi', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 972: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Fá', 'Sol', 'Sol', 'Sol', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Fá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 973: Melhor individuo = ['Sol', 'Sol', 'Fá', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 974: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Dó', 'Si', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 975: Melhor individuo = ['Si', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 976: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Mi', 'Mi', 'Si', 'Ré', 'Dó'], Fitness = 20
# Geracao 977: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Lá', 'Si', 'Sol', 'Sol', 'Lá', 'Dó', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Si', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 978: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Si', 'Sol', 'Mi', 'Dó', 'Mi', 'Lá', 'Fá', 'Fá', 'Mi', 'Lá', 'Ré', 'Dó'], Fitness = 21
# Geracao 979: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Mi', 'Dó'], Fitness = 22
# Geracao 980: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Fá', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Mi', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 981: Melhor individuo = ['Sol', 'Sol', 'Si', 'Sol', 'Lá', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Sol', 'Dó', 'Mi', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 982: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Mi', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 983: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Dó', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 984: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Sol', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Mi', 'Dó', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 985: Melhor individuo = ['Lá', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 986: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Sol', 'Ré', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Mi', 'Dó', 'Dó', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Sol'], Fitness = 21
# Geracao 987: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 988: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Si', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Dó', 'Si', 'Dó', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 989: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Dó', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 990: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Si', 'Sol', 'Si', 'Lá', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 991: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Sol', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Dó', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Fá', 'Fá', 'Lá', 'Mi', 'Dó', 'Ré', 'Ré'], Fitness = 20
# Geracao 992: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Fá', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 993: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Sol', 'Fá', 'Sol', 'Sol', 'Fá', 'Sol', 'Ré', 'Dó', 'Sol', 'Lá', 'Sol', 'Mi', 'Dó', 'Sol', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 994: Melhor individuo = ['Sol', 'Sol', 'Ré', 'Si', 'Dó', 'Si', 'Sol', 'Sol', 'Sol', 'Lá', 'Ré', 'Dó', 'Sol', 'Si', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 995: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Lá', 'Sol', 'Si', 'Sol', 'Ré', 'Dó', 'Sol', 'Sol', 'Sol', 'Dó', 'Dó', 'Si', 'Lá', 'Fá', 'Sol', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 996: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Lá', 'Sol', 'Sol', 'Mi', 'Dó', 'Si', 'Lá', 'Fá', 'Dó', 'Si', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Geracao 997: Melhor individuo = ['Ré', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Dó', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Fá', 'Fá', 'Lá', 'Fá', 'Fá', 'Mi', 'Dó', 'Ré', 'Dó'], Fitness = 20
# Geracao 998: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Fá', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Dó', 'Fá', 'Lá', 'Fá', 'Fá', 'Sol', 'Dó', 'Ré', 'Dó'], Fitness = 21
# Geracao 999: Melhor individuo = ['Sol', 'Sol', 'Lá', 'Sol', 'Dó', 'Si', 'Sol', 'Sol', 'Lá', 'Sol', 'Ré', 'Dó', 'Fá', 'Sol', 'Sol', 'Mi', 'Dó', 'Fá', 'Lá', 'Fá', 'Fá', 'Si', 'Dó', 'Ré', 'Dó'], Fitness = 22
# Solução não encontrada dentro do número máximo de gerações.
